# %%
import matplotlib.font_manager as fm
from matplotlib import rcParams

font_path = '/home/shariat/Documents/fonts/Helvetica.ttf'
fm.fontManager.addfont(font_path)           # add it globally
rcParams['font.family'] = 'Helvetica'  # set default

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Suppress common warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")
warnings.filterwarnings("ignore", message=".*X does not have valid feature names.*")

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    roc_auc_score,
    accuracy_score
)
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

# %%
# ────────────────────────────────────────────────
#                Data Loading & Preparation
# ────────────────────────────────────────────────

data = pd.read_csv('/home/shariat/Astronomy/TTV/Data/PS_2025.10.03_12.37.12.csv', comment='#')

features = [
    'pl_orbper', 'pl_orbsmax', 'pl_rade', 'pl_masse', 'pl_orbeccen',
    'pl_insol', 'pl_eqt', 'pl_orbincl', 'pl_trandep', 'pl_trandur',
    'pl_ratdor', 'pl_ratror', 'st_teff', 'st_rad', 'st_mass'
]
target = 'ttv_flag'

kepler_k2_data = data[data['disc_facility'].isin(['Kepler', 'K2'])].copy()
kepler_k2_data = kepler_k2_data.dropna(subset=[target])

print(f"Kepler + K2 rows: {len(kepler_k2_data)}")
print("Class distribution BEFORE processing:")
print(kepler_k2_data[target].value_counts())
print(kepler_k2_data[target].value_counts(normalize=True).round(4))

# Median imputation for missing values
for col in features:
    if col in kepler_k2_data.columns:
        kepler_k2_data[col] = kepler_k2_data[col].fillna(kepler_k2_data[col].median())

X = kepler_k2_data[features].values
y = kepler_k2_data[target].values.astype(int)

scaler = StandardScaler()
X = scaler.fit_transform(X)
# Out:
# Kepler + K2 rows: 30654
# Class distribution BEFORE processing:
# ttv_flag
# 0.0    25810
# 1.0     4844
# Name: count, dtype: int64
# ttv_flag
# 0.0    0.842
# 1.0    0.158
# Name: proportion, dtype: float64

# %%
# ────────────────────────────────────────────────
#          Experiment Settings
# ────────────────────────────────────────────────

experiment_name   = "best_model"

use_smote         = True
use_scale_pos_weight = True   # XGBoost's built-in way to handle imbalance

# Single fixed configuration for XGBoost
xgb_params = {
    'n_estimators':       200,
    'max_depth':          None,
    'learning_rate':      0.95,
    'subsample':          0.8,
    'colsample_bytree':   0.8,
    'min_child_weight':   1,
    'gamma':              0.12,
    'reg_lambda':         1.0,
    'reg_alpha':          0.75,
    'random_state':       42,
    'n_jobs':             -1,
    'eval_metric':        'auc',
    'verbosity':          0,
    'scale_pos_weight':   (y == 0).sum() / (y == 1).sum() if use_scale_pos_weight else 1
}

# %%
# ────────────────────────────────────────────────
#               20-Fold Cross-Validation
# ────────────────────────────────────────────────

n_splits = 20
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

accuracy_scores  = []
precision_scores = []
recall_scores    = []
f1_scores        = []
auc_scores       = []
cm_list          = []
tpr_list         = []
fpr_list         = []

smote = SMOTE(random_state=42, sampling_strategy='auto')

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    print(f"\nFold {fold+1}/{n_splits}")
    
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Apply SMOTE only to training data
    if use_smote:
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
        print(f" After SMOTE → class counts: {np.bincount(y_train_res)} (shape: {X_train_res.shape})")
    else:
        X_train_res, y_train_res = X_train, y_train
        print(" No SMOTE applied")

    # Create and fit XGBoost with fixed parameters
    model = XGBClassifier(**xgb_params)
    model.fit(X_train_res, y_train_res)

    # Evaluate on validation fold
    y_pred = model.predict(X_val)
    y_pred_proba = model.predict_proba(X_val)[:, 1]

    acc = accuracy_score(y_val, y_pred)
    prec = precision_score(y_val, y_pred, zero_division=0)
    rec = recall_score(y_val, y_pred, zero_division=0)
    f1 = f1_score(y_val, y_pred, zero_division=0)
    auc = roc_auc_score(y_val, y_pred_proba)

    accuracy_scores.append(acc)
    precision_scores.append(prec)
    recall_scores.append(rec)
    f1_scores.append(f1)
    auc_scores.append(auc)

    cm_list.append(confusion_matrix(y_val, y_pred))

    fpr, tpr, _ = roc_curve(y_val, y_pred_proba)
    common_fpr = np.linspace(0, 1, 100)
    tpr_interp = np.interp(common_fpr, fpr, tpr)
    tpr_list.append(tpr_interp)
    fpr_list.append(common_fpr)

    print(f" Acc: {acc:.4f}  Prec: {prec:.4f}  Rec: {rec:.4f}  F1: {f1:.4f}  AUC: {auc:.4f}")
# Out:
# Fold 1/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8858  Prec: 0.5954  Rec: 0.8636  F1: 0.7049  AUC: 0.9457
#
# Fold 2/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8956  Prec: 0.6220  Rec: 0.8636  F1: 0.7232  AUC: 0.9350
#
# Fold 3/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8865  Prec: 0.6056  Rec: 0.8058  F1: 0.6915  AUC: 0.9297
#
# Fold 4/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8787  Prec: 0.5800  Rec: 0.8388  F1: 0.6858  AUC: 0.9316
#
# Fold 5/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8917  Prec: 0.6067  Rec: 0.8926  F1: 0.7224  AUC: 0.9410
#
# Fold 6/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8663  Prec: 0.5524  Rec: 0.8058  F1: 0.6555  AUC: 0.9197
#
# Fold 7/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8898  Prec: 0.6058  Rec: 0.8636  F1: 0.7121  AUC: 0.9327
#
# Fold 8/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8676  Prec: 0.5556  Rec: 0.8058  F1: 0.6577  AUC: 0.9243
#
# Fold 9/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8800  Prec: 0.5843  Rec: 0.8306  F1: 0.6860  AUC: 0.9354
#
# Fold 10/20
#  After SMOTE → class counts: [24519 24519] (shape: (49038, 15))
#  Acc: 0.8787  Prec: 0.5791  Rec: 0.8471  F1: 0.6879  AUC: 0.9349
#
# Fold 11/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8748  Prec: 0.5718  Rec: 0.8354  F1: 0.6789  AUC: 0.9366
#
# Fold 12/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8904  Prec: 0.6140  Rec: 0.8313  F1: 0.7063  AUC: 0.9366
#
# Fold 13/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8989  Prec: 0.6384  Rec: 0.8354  F1: 0.7237  AUC: 0.9465
#
# Fold 14/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8721  Prec: 0.5662  Rec: 0.8272  F1: 0.6722  AUC: 0.9321
#
# Fold 15/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8851  Prec: 0.6006  Rec: 0.8140  F1: 0.6912  AUC: 0.9345
#
# Fold 16/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8819  Prec: 0.5916  Rec: 0.8140  F1: 0.6852  AUC: 0.9148
#
# Fold 17/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8760  Prec: 0.5747  Rec: 0.8264  F1: 0.6780  AUC: 0.9095
#
# Fold 18/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8740  Prec: 0.5702  Rec: 0.8223  F1: 0.6734  AUC: 0.9225
#
# Fold 19/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.9067  Prec: 0.6562  Rec: 0.8595  F1: 0.7442  AUC: 0.9465
#
# Fold 20/20
#  After SMOTE → class counts: [24520 24520] (shape: (49040, 15))
#  Acc: 0.8688  Prec: 0.5581  Rec: 0.8140  F1: 0.6622  AUC: 0.9188

# %%
# ────────────────────────────────────────────────
#                  Summary Results
# ────────────────────────────────────────────────

print(f"\n{'═'*50}")
print(f"EXPERIMENT: {experiment_name}")
print(f"SMOTE used: {use_smote} | scale_pos_weight used: {use_scale_pos_weight}")
print(f"XGBoost parameters: {xgb_params}")
print(f"{'═'*50}")
print(f"Accuracy:  {np.mean(accuracy_scores):.4f} ± {np.std(accuracy_scores):.4f}")
print(f"Precision: {np.mean(precision_scores):.4f} ± {np.std(precision_scores):.4f}")
print(f"Recall:    {np.mean(recall_scores):.4f} ± {np.std(recall_scores):.4f}")
print(f"F1 Score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"ROC-AUC:   {np.mean(auc_scores):.4f} ± {np.std(auc_scores):.4f}")
print(f"{'═'*50}\n")
# Out:
# ══════════════════════════════════════════════════
# EXPERIMENT: best_model
# SMOTE used: True | scale_pos_weight used: True
# XGBoost parameters: {'n_estimators': 200, 'max_depth': None, 'learning_rate': 0.95, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 1, 'gamma': 0.12, 'reg_lambda': 1.0, 'reg_alpha': 0.75, 'random_state': 42, 'n_jobs': -1, 'eval_metric': 'auc', 'verbosity': 0, 'scale_pos_weight': np.float64(5.3282411230388105)}
# ══════════════════════════════════════════════════
# Accuracy:  0.8825 ± 0.0106
# Precision: 0.5914 ± 0.0270
# Recall:    0.8348 ± 0.0232
# F1 Score:  0.6921 ± 0.0235
# ROC-AUC:   0.9314 ± 0.0101
# ══════════════════════════════════════════════════

# %%
# ────────────────────────────────────────────────
#          Average Confusion Matrix
# ────────────────────────────────────────────────

avg_cm = np.mean(cm_list, axis=0).astype(int)

plt.figure(figsize=(4.2, 4))
sns.heatmap(avg_cm, annot=True, fmt='d', cmap='Greens', cbar=False,
            annot_kws={"size": 16})
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks([0.5, 1.5], ['No TTV', 'TTV'])
plt.yticks([0.5, 1.5], ['No TTV', 'TTV'])
#plt.savefig('/home/shariat/Astronomy/TTV/XGBoost/Kepler/figures/kepler_xgb_20fold_singleconfig_cm_n_200_depth_none_lr_95_gamma_12_alpha_75_child_1.pdf')
plt.savefig('/home/shariat/Astronomy/TTV/figures/XGBoostKepler_cm.pdf')
plt.show()

# %%
# ────────────────────────────────────────────────
#             Averaged ROC Curve
# ────────────────────────────────────────────────

mean_tpr = np.mean(tpr_list, axis=0)
std_tpr  = np.std(tpr_list, axis=0)
mean_fpr = fpr_list[0]

plt.figure(figsize=(4.5, 4))
plt.plot(mean_fpr, mean_tpr,
         label=f'Mean AUC = {np.mean(auc_scores):.4f} $\pm$ {np.std(auc_scores):.4f}',
         color='green', lw=2.2)
plt.fill_between(mean_fpr, mean_tpr - std_tpr, mean_tpr + std_tpr,
                 color='green', alpha=0.18)
plt.plot([0, 1], [0, 1], linestyle='--', color='green', alpha=0.5)
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.legend(loc='lower right', fontsize=11)
plt.grid(alpha=0.18)
plt.xlim([0, 1])
plt.ylim([0, 1.02])
#plt.savefig('/home/shariat/Astronomy/TTV/XGBoost/Kepler/figures/kepler_xgb_20fold_singleconfig_roc_n_100_depth_none_lr_95_gamma_12_alpha_75_child_1.pdf')
plt.savefig('/home/shariat/Astronomy/TTV/figures/XGBoostKepler_roc.pdf')
plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_13395/3751029555.py:11: SyntaxWarning: invalid escape sequence '\p'
#   label=f'Mean AUC = {np.mean(auc_scores):.4f} $\pm$ {np.std(auc_scores):.4f}',

# %%
# ────────────────────────────────────────────────
# TOP 5 FEATURE IMPORTANCE – XGBoost (gain) – Kepler + K2
# ────────────────────────────────────────────────

importances = model.feature_importances_
feature_names = features  # your original list of 15 features

# Create DataFrame and sort by importance
fi_df = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
}).sort_values('importance', ascending=False).reset_index(drop=True)

# ─── Print only top 5 ──────────────────────────────────────────
print("\n" + "═"*60)
print("Top 5 Most Important Features (XGBoost – gain) – Kepler + K2")
print("═"*60)
print(fi_df.head(5).round(5))

# ─── Plot only top 5 ───────────────────────────────────────────
plt.figure(figsize=(4.5, 3))  # smaller figure for top 5
sns.barplot(
    data=fi_df.head(5),
    x='importance',
    y='feature',
    palette='Greens'
)
plt.xlabel('Importance (gain)', fontsize=11)
plt.ylabel('Feature', fontsize=11)
plt.grid(axis='x', alpha=0.25)

# Save to Kepler-specific folder (you can adjust paths)
plt.savefig('/home/shariat/Astronomy/TTV/XGBoost/Kepler/figures/kepler_xgb_top5_feature_importance.pdf')
plt.savefig('/home/shariat/Astronomy/TTV/figures/XGBoostKepler_feature.pdf')

plt.show()
# Out:
# ════════════════════════════════════════════════════════════
# Top 5 Most Important Features (XGBoost – gain) – Kepler + K2
# ════════════════════════════════════════════════════════════
#       feature  importance
# 0    pl_masse     0.15071
# 1     pl_rade     0.09524
# 2      pl_eqt     0.07824
# 3  pl_orbsmax     0.06919
# 4     st_teff     0.06824
