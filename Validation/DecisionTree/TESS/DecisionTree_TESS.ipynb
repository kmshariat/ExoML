# %%
import matplotlib.font_manager as fm
from matplotlib import rcParams

font_path = '/home/shariat/Documents/fonts/Helvetica.ttf'
fm.fontManager.addfont(font_path)           # add it globally
rcParams['font.family'] = 'Helvetica'  # set default

# %%
import numpy as np
import pandas as pd
import joblib
import os
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# ========================= CONFIG =========================
MODEL_DIR = "/home/shariat/Astronomy/TTV/Validation/Models"
DATA_PATH = "/home/shariat/Astronomy/TTV/Validation/Data/PS_2026.06.08_12.38.35_new.csv"

MODEL_NAME = "tess_decisiontree_model.pkl"
SCALER_NAME = "tess_decisiontree_scaler.pkl"

THRESHOLD = 0.5

features = [
    'pl_orbper', 'pl_orbsmax', 'pl_rade', 'pl_masse', 'pl_orbeccen',
    'pl_insol', 'pl_eqt', 'pl_orbincl', 'pl_trandep', 'pl_trandur',
    'pl_ratdor', 'pl_ratror', 'st_teff', 'st_rad', 'st_mass'
]

target = 'ttv_flag'

# %%
def load_model_and_scaler():
    model_path = os.path.join(MODEL_DIR, MODEL_NAME)
    scaler_path = os.path.join(MODEL_DIR, SCALER_NAME)
    
    model = joblib.load(model_path)
    scaler = joblib.load(scaler_path)
    
    print(f"Loaded Decision Tree Model: {MODEL_NAME}")
    print(f"Loaded Scaler: {SCALER_NAME}")
    print(f"Prediction Threshold: {THRESHOLD}")
    return model, scaler

# %%
def preprocess_data():
    print("Loading and preprocessing TESS data...")
    data = pd.read_csv(DATA_PATH, comment='#')
    
    data['disc_pubdate'] = pd.to_datetime(data['disc_pubdate'], format='%Y-%m', errors='coerce')
    start_date = pd.to_datetime('2025-11')
    end_date = pd.to_datetime('2026-06')
    data = data[(data['disc_pubdate'] >= start_date) & (data['disc_pubdate'] <= end_date)]
    
    tess_data = data[data['disc_facility'].isin(['Transiting Exoplanet Survey Satellite (TESS)'])].copy()
    tess_data = tess_data.dropna(subset=[target])
    
    print(f"Total TESS samples: {len(tess_data)}")
    print("Actual TTV distribution:")
    print(tess_data[target].value_counts())
    
    # Median imputation (same as training)
    for col in features:
        if col in tess_data.columns:
            median_val = tess_data[col].median()
            tess_data[col] = tess_data[col].fillna(0 if pd.isna(median_val) else median_val)
    
    tess_data = tess_data.dropna(subset=features)
    
    X = tess_data[features].values
    y_true = tess_data[target].values.astype(int)
    
    return tess_data, X, y_true

# %%
if __name__ == "__main__":
    model, scaler = load_model_and_scaler()
    df, X_raw, y_true = preprocess_data()
    
    X_scaled = scaler.transform(X_raw)
    
    y_proba = model.predict_proba(X_scaled)[:, 1]
    y_pred = (y_proba >= THRESHOLD).astype(int)
    
    # Results
    results = df.copy()
    results['ttv_predicted'] = y_pred
    results['ttv_probability'] = y_proba.round(4)
    results['confidence'] = np.where(y_pred == 1, y_proba, 1 - y_proba).round(4)
    
    print("\n" + "="*80)
    print(f"TESS DECISION TREE PREDICTIONS (Threshold = {THRESHOLD})")
    print("="*80)
    
    display_cols = ['pl_name', 'disc_pubdate', 'disc_facility', target, 
                   'ttv_predicted', 'ttv_probability', 'confidence']
    
    print(results[display_cols].sort_values(by='ttv_probability', ascending=False).to_string(index=False))
    
    # Evaluation with safe handling
    if len(y_true) > 0:
        print(f"\nAccuracy: {accuracy_score(y_true, y_pred):.4f}")
        
        # Safe Classification Report
        unique_classes = np.unique(np.concatenate([y_true, y_pred]))
        if len(unique_classes) == 1:
            print("\n Only one class present in data/predictions. Classification Report skipped.")
            print("True labels :", np.unique(y_true))
            print("Predicted labels:", np.unique(y_pred))
        else:
            print("\n📊 Classification Report:")
            print(classification_report(y_true, y_pred, 
                                      target_names=['No TTV', 'TTV'], 
                                      zero_division=0))
        
        # Confusion Matrix
        cm = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(6, 5))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                    xticklabels=['No TTV', 'TTV'], 
                    yticklabels=['No TTV', 'TTV'])
        plt.title(f'Confusion Matrix - TESS DECISION TREE (Threshold={THRESHOLD})')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.show()
    
    # Save predictions
    output_path = f"/home/shariat/Astronomy/TTV/Validation/predictions_tess_decisiontree_th{THRESHOLD}.csv"
    results.to_csv(output_path, index=False)
    print(f"\n Predictions saved to: {output_path}")
# Out:
# Loaded Decision Tree Model: tess_decisiontree_model.pkl
# Loaded Scaler: tess_decisiontree_scaler.pkl
# Prediction Threshold: 0.5
# Loading and preprocessing TESS data...
# Total TESS samples: 339
# Actual TTV distribution:
# ttv_flag
# 0    318
# 1     21
# Name: count, dtype: int64
#
# ================================================================================
# TESS DECISION TREE PREDICTIONS (Threshold = 0.5)
# ================================================================================
#         pl_name disc_pubdate                                disc_facility  ttv_flag  ttv_predicted  ttv_probability  confidence
#       NGTS-34 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5422 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5777 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5788 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-1243 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-1232 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-6041 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           1.0000      1.0000
#      TOI-6692 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-6677 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-6707 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#       TOI-808 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#       TOI-912 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#       TOI-912 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-7510 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           1.0000      1.0000
#      TOI-4405 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-4662 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#  TIC 32032563 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
# TIC 198190129 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5734 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5380 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5502 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5595 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-2094 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-5728 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
#      TOI-2094 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           1.0000      1.0000
# TIC 290487717 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.9333      0.9333
#      TOI-5736 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.9333      0.9333
#      TOI-2431 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.9333      0.9333
#      TOI-5630 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.9333      0.9333
#      TOI-4311 b   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.9333      0.9333
#      TOI-5614 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.8750      0.8750
#      TOI-6692 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.8571      0.8571
#      TOI-7510 d   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.8182      0.8182
#      TOI-2449 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#       NGTS-35 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#      TOI-4507 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#  TIC 87422071 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#  TIC 87422071 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#      TOI-5502 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#      TOI-6677 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#      TOI-4507 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#      TOI-4507 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7500      0.7500
#      TOI-7510 d   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.7500      0.7500
#      TOI-7510 d   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.7500      0.7500
#      TOI-4156 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6667      0.6667
#      TOI-2267 d   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6667      0.6667
#       TOI-201 d   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6667      0.6667
#      TOI-2518 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6667      0.6667
#      TOI-5788 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6667      0.6667
#       TOI-205 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6667      0.6667
# TIC 160113658 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6471      0.6471
#      TOI-5614 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6471      0.6471
#      TOI-5595 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6471      0.6471
# TIC 188624430 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6471      0.6471
#      TOI-3896 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6471      0.6471
#      TOI-2453 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6471      0.6471
#       NGTS-35 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6471      0.6471
#      TOI-2345 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6364      0.6364
#      TOI-2345 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6364      0.6364
#      TOI-4940 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-5335 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-5335 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#       TOI-938 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#       TOI-938 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#       TOI-941 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      LHS 1903 d   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#       TOI-921 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#       TOI-921 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-1718 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-6109 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5882      0.5882
#      TOI-6109 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5882      0.5882
#      TOI-6954 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-6954 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-6080 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-1036 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#  TIC 77552382 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-6080 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-4930 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-7510 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5882      0.5882
#       TOI-883 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-4029 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-4930 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-4029 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-5926 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-5624 d   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-1722 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-1718 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-4747 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-4940 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-4747 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5882      0.5882
#      TOI-6109 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5882      0.5882
#      TOI-3896 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
#       TOI-929 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
#       TOI-929 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
#      TOI-6393 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
#      TOI-1750 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
#      TOI-1105 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
#      TOI-1105 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
# TIC 423703298 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
# TIC 154870955 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5556      0.5556
#      TOI-5624 e   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5000      0.5000
#      TOI-1226 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5000      0.5000
#      TOI-6041 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.4375      0.5625
#      TOI-7510 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.4375      0.5625
#      TOI-6448 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.4375      0.5625
#      TOI-7510 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.4167      0.5833
#      TOI-1232 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.4000      0.6000
#      LHS 1903 c   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3750      0.6250
# TIC 245076932 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3750      0.6250
#      TOI-1232 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.3750      0.6250
#      TOI-7510 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.3750      0.6250
#      TOI-2449 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3750      0.6250
#      TOI-4156 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#  TIC 24750448 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
# TIC 445839811 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#       TOI-697 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#      TOI-5515 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#       TOI-283 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#      TOI-2518 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
# TIC 270471727 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#      TOI-1873 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#      TOI-5515 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
# TIC 294329732 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#       TOI-697 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#       TOI-808 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3333      0.6667
#      TOI-5160 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3000      0.7000
#       TOI-799 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3000      0.7000
#      TOI-2071 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.3000      0.7000
# TIC 270471727 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2667      0.7333
#      TOI-2227 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2667      0.7333
#      TOI-5734 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
#      TOI-5789 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
#      TOI-5788 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
#      TOI-5788 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
#      TOI-6699 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
#      TOI-7166 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
#      TOI-7166 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
#      TOI-7166 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2500      0.7500
# TIC 183374187 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
#       TOI-333 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
#      TOI-4511 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
#       TOI-333 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
#      TOI-5422 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
#      TOI-1036 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
#      TOI-6707 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
#      TOI-5380 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1333      0.8667
# TIC 320419023 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1250      0.8750
#      TOI-4511 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1250      0.8750
#      TOI-7384 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1250      0.8750
#      TOI-1080 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1250      0.8750
#      TOI-1873 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1250      0.8750
#      TOI-4156 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1250      0.8750
#      TOI-5624 e   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.1053      0.8947
#      TOI-4311 c   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1053      0.8947
#      TOI-4311 b   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0588      0.9412
# TIC 231949697 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 231949697 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 206466666 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 18942729 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 178172313 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 161045582 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 153919886 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 147027702 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7155 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7009 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7009 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7155 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7384 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7510 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.0000      1.0000
#      TOI-7333 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7333 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-883 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 38828280 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 437041147 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 390586021 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 34085383 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 24750448 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 249022743 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 260969020 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-375 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-375 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-3288 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-3288 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-3288 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4030 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4030 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-3862 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4156 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-3862 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4311 c   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4363 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4405 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4363 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4495 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.0000      1.0000
#      TOI-4495 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.0000      1.0000
#      TOI-4513 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4513 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4529 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4529 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4529 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4552 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4552 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4561 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4561 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-799 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 142589416 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7008 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-7008 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 349520724 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 356227008 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 38825265 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4666 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4666 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4662 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4640 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4640 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4578 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4578 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4666 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2093 c   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2104 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2104 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2133 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5007 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4898 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-4898 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5007 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2267 d   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2267 d   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2345 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2345 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2345 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2431 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2453 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2654 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2654 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-283 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5160 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-521 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2133 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5159 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5159 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2093 c   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5349 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#    TOI-5292 A b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#    TOI-5292 A b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5349 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5486 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5489 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5489 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5486 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5489 c   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5532 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5532 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5599 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5599 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5605 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5605 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5489 c   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1648 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1722 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1732 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1732 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1752 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1752 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1752 c   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1750 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1752 c   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1756 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1814 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1756 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-521 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2200 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2200 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2227 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1839 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1839 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1839 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1814 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-209 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2092 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2071 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-201 d   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5624 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5624 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5624 c   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5624 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5624 c   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5624 d   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-2092 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-205 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5716 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5716 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5734 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5728 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5736 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5777 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5789 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5736 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5916 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 62895484 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 67686059 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 65612701 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 77319217 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 86380416 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5630 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-209 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1080 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#  TIC 88692598 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1243 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1226 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1269 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1291 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1291 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1269 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1466 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-159 b   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-159 b   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1648 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5916 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5926 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5938 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-1466 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-5938 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-6109 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              0           0.0000      1.0000
#      TOI-6281 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-6281 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-6393 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-6448 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-6699 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-6716 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      TOI-6716 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 139702105 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
# TIC 117642575 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      LHS 1903 d   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      LHS 1903 c   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      LHS 1903 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#       TOI-941 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#      LHS 1903 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.0000      1.0000
#
# Accuracy: 0.6962
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       No TTV       0.95      0.71      0.81       318
#          TTV       0.10      0.48      0.16        21
#
#     accuracy                           0.70       339
#    macro avg       0.53      0.59      0.49       339
# weighted avg       0.90      0.70      0.77       339
#  Predictions saved to: /home/shariat/Astronomy/TTV/Validation/predictions_tess_decisiontree_th0.5.csv
