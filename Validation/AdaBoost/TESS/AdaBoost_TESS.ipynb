# %%
import matplotlib.font_manager as fm
from matplotlib import rcParams

font_path = '/home/shariat/Documents/fonts/Helvetica.ttf'
fm.fontManager.addfont(font_path)           # add it globally
rcParams['font.family'] = 'Helvetica'  # set default

# %%
import numpy as np
import pandas as pd
import joblib
import os
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# ========================= CONFIG =========================
MODEL_DIR = "/home/shariat/Astronomy/TTV/Validation/Models"
DATA_PATH = "/home/shariat/Astronomy/TTV/Validation/Data/PS_2026.06.08_12.38.35_new.csv"

MODEL_NAME = "tess_adaboost_model.pkl"
SCALER_NAME = "tess_adaboost_scaler.pkl"

THRESHOLD = 0.5

features = [
    'pl_orbper', 'pl_orbsmax', 'pl_rade', 'pl_masse', 'pl_orbeccen',
    'pl_insol', 'pl_eqt', 'pl_orbincl', 'pl_trandep', 'pl_trandur',
    'pl_ratdor', 'pl_ratror', 'st_teff', 'st_rad', 'st_mass'
]

target = 'ttv_flag'

# %%
def load_model_and_scaler():
    model_path = os.path.join(MODEL_DIR, MODEL_NAME)
    scaler_path = os.path.join(MODEL_DIR, SCALER_NAME)
    
    model = joblib.load(model_path)
    scaler = joblib.load(scaler_path)
    
    print(f"Loaded AdaBoost Model: {MODEL_NAME}")
    print(f"Loaded Scaler: {SCALER_NAME}")
    print(f"Prediction Threshold: {THRESHOLD}")
    return model, scaler

# %%
def preprocess_data():
    print("Loading and preprocessing TESS data...")
    data = pd.read_csv(DATA_PATH, comment='#')
    
    data['disc_pubdate'] = pd.to_datetime(data['disc_pubdate'], format='%Y-%m', errors='coerce')
    start_date = pd.to_datetime('2025-11')
    end_date = pd.to_datetime('2026-06')
    data = data[(data['disc_pubdate'] >= start_date) & (data['disc_pubdate'] <= end_date)]
    
    tess_data = data[data['disc_facility'].isin(['Transiting Exoplanet Survey Satellite (TESS)'])].copy()
    tess_data = tess_data.dropna(subset=[target])
    
    print(f"Total TESS samples: {len(tess_data)}")
    print("Actual TTV distribution:")
    print(tess_data[target].value_counts())
    
    # Median imputation (same as training)
    for col in features:
        if col in tess_data.columns:
            median_val = tess_data[col].median()
            tess_data[col] = tess_data[col].fillna(0 if pd.isna(median_val) else median_val)
    
    tess_data = tess_data.dropna(subset=features)
    
    X = tess_data[features].values
    y_true = tess_data[target].values.astype(int)
    
    return tess_data, X, y_true

# %%
if __name__ == "__main__":
    model, scaler = load_model_and_scaler()
    df, X_raw, y_true = preprocess_data()
    
    X_scaled = scaler.transform(X_raw)
    
    y_proba = model.predict_proba(X_scaled)[:, 1]
    y_pred = (y_proba >= THRESHOLD).astype(int)
    
    # Results
    results = df.copy()
    results['ttv_predicted'] = y_pred
    results['ttv_probability'] = y_proba.round(4)
    results['confidence'] = np.where(y_pred == 1, y_proba, 1 - y_proba).round(4)
    
    print("\n" + "="*80)
    print(f"TESS ADABOOST PREDICTIONS (Threshold = {THRESHOLD})")
    print("="*80)
    
    display_cols = ['pl_name', 'disc_pubdate', 'disc_facility', target, 
                   'ttv_predicted', 'ttv_probability', 'confidence']
    
    print(results[display_cols].sort_values(by='ttv_probability', ascending=False).to_string(index=False))
    
    # Evaluation with safe handling
    if len(y_true) > 0:
        print(f"\nAccuracy: {accuracy_score(y_true, y_pred):.4f}")
        
        # Safe Classification Report
        unique_classes = np.unique(np.concatenate([y_true, y_pred]))
        if len(unique_classes) == 1:
            print("\n Only one class present in data/predictions. Classification Report skipped.")
            print("True labels :", np.unique(y_true))
            print("Predicted labels:", np.unique(y_pred))
        else:
            print("\n📊 Classification Report:")
            print(classification_report(y_true, y_pred, 
                                      target_names=['No TTV', 'TTV'], 
                                      zero_division=0))
        
        # Confusion Matrix
        cm = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(6, 5))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                    xticklabels=['No TTV', 'TTV'], 
                    yticklabels=['No TTV', 'TTV'])
        plt.title(f'Confusion Matrix - TESS ADABOOST (Threshold={THRESHOLD})')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.show()
    
    # Save predictions
    output_path = f"/home/shariat/Astronomy/TTV/Validation/predictions_tess_adaboost_th{THRESHOLD}.csv"
    results.to_csv(output_path, index=False)
    print(f"\n Predictions saved to: {output_path}")
# Out:
# Loaded AdaBoost Model: tess_adaboost_model.pkl
# Loaded Scaler: tess_adaboost_scaler.pkl
# Prediction Threshold: 0.5
# Loading and preprocessing TESS data...
# Total TESS samples: 339
# Actual TTV distribution:
# ttv_flag
# 0    318
# 1     21
# Name: count, dtype: int64
#
# ================================================================================
# TESS ADABOOST PREDICTIONS (Threshold = 0.5)
# ================================================================================
#         pl_name disc_pubdate                                disc_facility  ttv_flag  ttv_predicted  ttv_probability  confidence
#      TOI-4507 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.7796      0.7796
#      TOI-5614 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6866      0.6866
# TIC 154870955 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6800      0.6800
#       NGTS-35 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6740      0.6740
#      TOI-4507 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6699      0.6699
#      TOI-5614 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6578      0.6578
#       TOI-929 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6542      0.6542
#      TOI-6692 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6484      0.6484
#      TOI-4662 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6343      0.6343
#       TOI-929 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6248      0.6248
# TIC 160113658 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6236      0.6236
#      TOI-4405 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6194      0.6194
#      TOI-2449 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6148      0.6148
#      TOI-7510 d   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.6078      0.6078
# TIC 188624430 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6061      0.6061
#      TOI-5777 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6059      0.6059
#       TOI-201 d   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.6036      0.6036
#      TOI-6041 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5960      0.5960
#  TIC 24750448 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5761      0.5761
#      TOI-5734 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5740      0.5740
#      TOI-5624 d   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5717      0.5717
#      TOI-7510 d   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5711      0.5711
# TIC 198190129 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5707      0.5707
#      TOI-3896 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5691      0.5691
#      TOI-5380 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5676      0.5676
#      TOI-5595 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5667      0.5667
#       TOI-205 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5615      0.5615
#      TOI-4495 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5601      0.5601
#      TOI-1232 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5567      0.5567
#       NGTS-35 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5564      0.5564
#      TOI-6041 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5528      0.5528
#       NGTS-34 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5502      0.5502
#       TOI-941 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5481      0.5481
#      TOI-7510 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5464      0.5464
#      TOI-4495 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         1              1           0.5441      0.5441
#      TOI-4930 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5433      0.5433
#      TOI-5595 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5354      0.5354
#      TOI-6692 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5247      0.5247
#      TOI-2227 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5244      0.5244
#      TOI-1105 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0.5144      0.5144
# TIC 320419023 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              1           0
01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2540      0.7460
#      TOI-5007 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2532      0.7468
#      TOI-2200 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2526      0.7474
#      TOI-5736 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2485      0.7515
#       TOI-375 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2476      0.7524
#      LHS 1903 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2464      0.7536
#      TOI-6707 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2464      0.7536
#      TOI-5422 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2463      0.7537
#      TOI-1466 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2441      0.7559
#      TOI-2345 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2439      0.7561
#      TOI-5489 c   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2436      0.7564
#      TOI-1756 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2412      0.7588
#       TOI-159 b   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2404      0.7596
#      TOI-5624 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2396      0.7604
#      TOI-5736 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2395      0.7605
#      TOI-1648 b   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2384      0.7616
# TIC 231949697 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2376      0.7624
#      TOI-1814 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2374      0.7626
#      TOI-5599 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2371      0.7629
#      TOI-2267 d   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2360      0.7640
#  TIC 65612701 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2357      0.7643
#      TOI-4552 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2335      0.7665
#      TOI-4529 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2320      0.7680
#    TOI-5292 A b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2316      0.7684
#      TOI-4666 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2312      0.7688
#  TIC 88692598 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2310      0.7690
#      TOI-1752 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2292      0.7708
#  TIC 87422071 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2284      0.7716
#      TOI-5349 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2276      0.7724
#      TOI-4311 c   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2271      0.7729
#      TOI-2133 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2263      0.7737
#      LHS 1903 c   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2250      0.7750
#      TOI-6716 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2245      0.7755
#      TOI-5789 c   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2243      0.7757
#      TOI-2267 d   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2238      0.7762
#      TOI-4666 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2228      0.7772
#      TOI-4552 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2213      0.7787
#      TOI-2345 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2209      0.7791
#      TOI-1752 c   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2204      0.7796
#      TOI-1291 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2151      0.7849
#      TOI-3862 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2151      0.7849
#      TOI-4666 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2123      0.7877
#      TOI-5916 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2122      0.7878
#      TOI-7166 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2103      0.7897
# TIC 231949697 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2078      0.7922
#      TOI-5349 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2055      0.7945
#      TOI-5007 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2047      0.7953
#      TOI-5916 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2042      0.7958
#      TOI-7009 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2007      0.7993
#       TOI-159 b   2026-05-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.2003      0.7997
#      TOI-2345 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1986      0.8014
#       TOI-521 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1980      0.8020
#      TOI-7166 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1950      0.8050
#       TOI-375 b   2026-01-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1934      0.8066
#      TOI-1752 c   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1917      0.8083
#      TOI-7166 b   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1909      0.8091
#      TOI-3288 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1906      0.8094
#    TOI-5292 A b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1851      0.8149
#      TOI-1752 b   2026-04-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1804      0.8196
#      TOI-2093 c   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1771      0.8229
#      TOI-2345 c   2025-12-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1763      0.8237
#      TOI-3288 b   2026-03-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1749      0.8251
#      LHS 1903 b   2026-02-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1608      0.8392
#      TOI-2093 c   2025-11-01 Transiting Exoplanet Survey Satellite (TESS)         0              0           0.1580      0.8420
#
# Accuracy: 0.8496
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#       No TTV       0.96      0.88      0.92       318
#          TTV       0.17      0.38      0.24        21
#
#     accuracy                           0.85       339
#    macro avg       0.56      0.63      0.58       339
# weighted avg       0.91      0.85      0.87       339
#  Predictions saved to: /home/shariat/Astronomy/TTV/Validation/predictions_tess_adaboost_th0.5.csv
